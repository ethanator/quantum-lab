# %% [markdown]
# **References**
#
# 1. [Qiskit Machine Learning Installation](https://qiskit.org/ecosystem/machine-learning/getting_started.html)

# %%
# !pip install 'qiskit[machine-learning]'
# Out:
# Requirement already satisfied: qiskit[machine-learning] in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (0.42.1)
# Requirement already satisfied: qiskit-terra==0.23.3 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from qiskit[machine-learning]) (0.23.3)
# Requirement already satisfied: qiskit-ibmq-provider==0.20.2 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from qiskit[machine-learning]) (0.20.2)
# Requirement already satisfied: qiskit-aer==0.12.0 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from qiskit[machine-learning]) (0.12.0)
# Requirement already satisfied: qiskit-machine-learning>=0.4.0 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from qiskit[machine-learning]) (0.6.0)
# Requirement already satisfied: scipy>=1.0 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from qiskit-aer==0.12.0->qiskit[machine-learning]) (1.10.1)
# Requirement already satisfied: numpy>=1.16.3 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from qiskit-aer==0.12.0->qiskit[machine-learning]) (1.23.5)
# Requirement already satisfied: urllib3>=1.21.1 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit[machine-learning]) (1.26.13)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit[machine-learning]) (2.8.2)
# Requirement already satisfied: requests>=2.19 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit[machine-learning]) (2.28.1)
# Requirement already satisfied: websockets>=10.0 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit[machine-learning]) (11.0.1)
# Requirement already satisfied: requests-ntlm<=1.1.0 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit[machine-learning]) (1.1.0)
# Requirement already satisfied: websocket-client>=1.5.1 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit[machine-learning]) (1.5.1)
# Requirement already satisfied: symengine>=0.9 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from qiskit-terra==0.23.3->qiskit[machine-learning]) (0.10.0)
# Requirement already satisfied: psutil>=5 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from qiskit-terra==0.23.3->qiskit[machine-learning]) (5.9.4)
# Requirement already satisfied: sympy>=1.3 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from qiskit-terra==0.23.3->qiskit[machine-learning]) (1.11.1)
# Requirement already satisfied: dill>=0.3 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from qiskit-terra==0.23.3->qiskit[machine-learning]) (0.3.5.1)
# Requirement already satisfied: rustworkx>=0.12.0 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from qiskit-terra==0.23.3->qiskit[machine-learning]) (0.12.1)
# Requirement already satisfied: stevedore>=3.0.0 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from qiskit-terra==0.23.3->qiskit[machine-learning]) (5.0.0)
# Requirement already satisfied: ply>=3.10 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from qiskit-terra==0.23.3->qiskit[machine-learning]) (3.11)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from qiskit-machine-learning>=0.4.0->qiskit[machine-learning]) (1.2.2)
# Requirement already satisfied: setuptools>=40.1.0 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from qiskit-machine-learning>=0.4.0->qiskit[machine-learning]) (65.5.0)
# Requirement already satisfied: fastdtw in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from qiskit-machine-learning>=0.4.0->qiskit[machine-learning]) (0.3.4)
# Requirement already satisfied: six>=1.5 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.0->qiskit-ibmq-provider==0.20.2->qiskit[machine-learning]) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.20.2->qiskit[machine-learning]) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.20.2->qiskit[machine-learning]) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.20.2->qiskit[machine-learning]) (2.0.4)
# Requirement already satisfied: cryptography>=1.3 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit[machine-learning]) (38.0.1)
# Requirement already satisfied: ntlm-auth>=1.0.2 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit[machine-learning]) (1.5.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from scikit-learn>=0.20.0->qiskit-machine-learning>=0.4.0->qiskit[machine-learning]) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from scikit-learn>=0.20.0->qiskit-machine-learning>=0.4.0->qiskit[machine-learning]) (3.1.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from stevedore>=3.0.0->qiskit-terra==0.23.3->qiskit[machine-learning]) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from sympy>=1.3->qiskit-terra==0.23.3->qiskit[machine-learning]) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from cryptography>=1.3->requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit[machine-learning]) (1.15.1)
# Requirement already satisfied: pycparser in /Users/ethan.chen/miniconda3/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit[machine-learning]) (2.21)

# %%
from qiskit.utils import algorithm_globals

algorithm_globals.random_seed = 42

# %%
from qiskit_machine_learning.datasets import ad_hoc_data

adhoc_dimension = 2
train_features, train_labels, test_features, test_labels, adhoc_total = ad_hoc_data(
    training_size=40,
    test_size=10,
    n=adhoc_dimension,
    gap=0.3,
    plot_data=False,
    one_hot=False,
    include_sample_total=True,
)

# %%
import matplotlib.pyplot as plt
import numpy as np


def plot_features(ax, features, labels, class_label, marker, face, edge, label):
    # A train plot
    ax.scatter(
        # x coordinate of labels where class is class_label
        features[np.where(labels[:] == class_label), 0],
        # y coordinate of labels where class is class_label
        features[np.where(labels[:] == class_label), 1],
        marker=marker,
        facecolors=face,
        edgecolors=edge,
        label=label,
    )


def plot_dataset(train_features, train_labels, test_features, test_labels, adhoc_total):
    plt.figure(figsize=(5, 5))
    plt.ylim(0, 2 * np.pi)
    plt.xlim(0, 2 * np.pi)
    plt.imshow(
        np.asmatrix(adhoc_total).T,
        interpolation="nearest",
        origin="lower",
        cmap="RdBu",
        extent=[0, 2 * np.pi, 0, 2 * np.pi],
    )

    # A train plot
    plot_features(plt, train_features, train_labels, 0, "s", "w", "b", "A train")

    # B train plot
    plot_features(plt, train_features, train_labels, 1, "o", "w", "r", "B train")

    # A test plot
    plot_features(plt, test_features, test_labels, 0, "s", "b", "w", "A test")

    # B test plot
    plot_features(plt, test_features, test_labels, 1, "o", "r", "w", "B test")

    plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0.0)
    plt.title("Ad hoc dataset")

    plt.show()

# %%
plot_dataset(train_features, train_labels, test_features, test_labels, adhoc_total)

# %%
from qiskit.circuit.library import ZZFeatureMap
from qiskit.primitives import Sampler
from qiskit.algorithms.state_fidelities import ComputeUncompute
from qiskit_machine_learning.kernels import FidelityQuantumKernel

adhoc_feature_map = ZZFeatureMap(feature_dimension=adhoc_dimension, reps=2, entanglement="linear")

sampler = Sampler()

fidelity = ComputeUncompute(sampler=sampler)

adhoc_kernel = FidelityQuantumKernel(fidelity=fidelity, feature_map=adhoc_feature_map)

# %%
from sklearn.svm import SVC

adhoc_svc = SVC(kernel=adhoc_kernel.evaluate)

adhoc_svc.fit(train_features, train_labels)

adhoc_score_callable_function = adhoc_svc.score(test_features, test_labels)

print(f"Callable kernel classification test score: {adhoc_score_callable_function}")
# Out:
# Callable kernel classification test score: 1.0

# %%
adhoc_matrix_train = adhoc_kernel.evaluate(x_vec=train_features)
adhoc_matrix_test = adhoc_kernel.evaluate(x_vec=test_features, y_vec=train_features)

fig, axs = plt.subplots(1, 2, figsize=(10, 5))

axs[0].imshow(
    np.asmatrix(adhoc_matrix_train), interpolation="nearest", origin="upper", cmap="Blues"
)
axs[0].set_title("Ad hoc training kernel matrix")

axs[1].imshow(np.asmatrix(adhoc_matrix_test), interpolation="nearest", origin="upper", cmap="Reds")
axs[1].set_title("Ad hoc testing kernel matrix")

plt.show()

# %%
adhoc_svc = SVC(kernel="precomputed")

adhoc_svc.fit(adhoc_matrix_train, train_labels)

adhoc_score_precomputed_kernel = adhoc_svc.score(adhoc_matrix_test, test_labels)

print(f"Precomputed kernel classification test score: {adhoc_score_precomputed_kernel}")
# Out:
# Precomputed kernel classification test score: 1.0

# %%
from qiskit_machine_learning.algorithms import QSVC

qsvc = QSVC(quantum_kernel=adhoc_kernel)

qsvc.fit(train_features, train_labels)

qsvc_score = qsvc.score(test_features, test_labels)

print(f"QSVC classification test score: {qsvc_score}")
# Out:
# QSVC classification test score: 1.0

# %%
print(f"Classification Model                    | Accuracy Score")
print(f"---------------------------------------------------------")
print(f"SVC using kernel as a callable function | {adhoc_score_callable_function:10.2f}")
print(f"SVC using precomputed kernel matrix     | {adhoc_score_precomputed_kernel:10.2f}")
print(f"QSVC                                    | {qsvc_score:10.2f}")
# Out:
# Classification Model                    | Accuracy Score
# ---------------------------------------------------------
# SVC using kernel as a callable function |       1.00
# SVC using precomputed kernel matrix     |       1.00
# QSVC                                    |       1.00
